# %% [markdown]
# # modify convert_ann for 1 file only

# %%
import os
import codecs

def convert_ann(ann):
    annfiles = [ann]
    
    tag_out = []
    
    for af in annfiles:
        
        annfile = af
        txtfile = annfile.replace(".ann", ".txt")
        paragraph_ = codecs.open(txtfile, "r", "utf-8")
        paragraph = paragraph_.read()
        paragraph = paragraph.strip()

        lastind = 0
        last_offset = 0
        
        with open(annfile) as f:
            for line in f:
                if line.startswith('T'):
                    
                    lsplit = line.split('\t')
                    tid, t_cinds, t_words = lsplit
                    t_words=t_words.strip()
                    try:
                        tsplit = t_cinds.split(' ')
                        tag = tsplit[0]
                        start = tsplit[1]
                        end = tsplit[-1]
                    except:
                        print t_cinds
                        print annfile
                    start=int(start)
                    end=int(end)
                    if start!=lastind:
                        owords=paragraph[lastind:start+last_offset].split(' ')
                        for oword in owords:
                            if oword.strip()!='':
                                tag_out+=[oword +' O']
                    lastind=end+last_offset
                    offset = 0
                    while(not paragraph[(start+offset):(end+offset)]==t_words):
                        if offset>50:
                            break
                        offset+=1
                    last_offset = offset
                    words=paragraph[(start+offset):(end+offset)].split(' ')
                    for wind in range(len(words)):
                        if words[wind].strip() == '':
                                next
                        else:
                            if wind==0:
                                tag_out+=[words[wind] +' B-'+tag]
                            else:
                                tag_out+=[words[wind] +' I-'+tag]

        owords=paragraph[lastind+1+offset:len(paragraph)].split(' ')
        for oword in owords:
                if oword.strip()!='':
                    tag_out+=[oword +' O']
        tag_out+=['']
                    
#     with open(path+'.txt', 'w') as out:
    return tag_out

# %%
gold=convert_ann('data/test/S0032386109005357.ann')[:-1]
# Out:
# /home/dan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:44: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal

# %% [markdown]
# ### I just pasted the notebook output into lists

# %%
words = [u'This',
  u'paper',
  u'proposes',
  u'a',
  u'sentence',
  u'stress',
  u'feedback',
  u'system',
  u'in',
  u'which',
  u'sentence',
  u'stress',
  u'prediction,',
  u'detection,',
  u'and',
  u'feedback',
  u'provision',
  u'models',
  u'are',
  u'combined.',
  u'This',
  u'system',
  u'provides',
  u'non-native',
  u'learners',
  u'with',
  u'feedback',
  u'on',
  u'sentence',
  u'stress',
  u'errors',
  u'so',
  u'that',
  u'they',
  u'can',
  u'improve',
  u'their',
  u'English',
  u'rhythm',
  u'and',
  u'fluency',
  u'in',
  u'a',
  u'self-study',
  u'setting.',
  u'The',
  u'sentence',
  u'stress',
  u'feedback',
  u'system',
  u'was',
  u'devised',
  u'to',
  u'predict',
  u'and',
  u'detect',
  u'the',
  u'sentence',
  u'stress',
  u'of',
  u'any',
  u'practice',
  u'sentence.',
  u'The',
  u'accuracy',
  u'of',
  u'the',
  u'prediction',
  u'and',
  u'detection',
  u'models',
  u'was',
  u'96.6%',
  u'and',
  u'84.1%,',
  u'respectively.',
  u'The',
  u'stress',
  u'feedback',
  u'provision',
  u'model',
  u'offers',
  u'positive',
  u'or',
  u'negative',
  u'stress',
  u'feedback',
  u'for',
  u'each',
  u'spoken',
  u'word',
  u'by',
  u'comparing',
  u'the',
  u'probability',
  u'of',
  u'the',
  u'predicted',
  u'stress',
  u'pattern',
  u'with',
  u'that',
  u'of',
  u'the',
  u'detected',
  u'stress',
  u'pattern.',
  u'In',
  u'an',
  u'experiment',
  u'that',
  u'evaluated',
  u'the',
  u'educational',
  u'effect',
  u'of',
  u'the',
  u'proposed',
  u'system',
  u'incorporated',
  u'in',
  u'our',
  u'CALL',
  u'system,',
  u'significant',
  u'improvements',
  u'in',
  u'accentedness',
  u'and',
  u'rhythm',
  u'were',
  u'seen',
  u'with',
  u'the',
  u'students',
  u'who',
  u'trained',
  u'with',
  u'our',
  u'system',
  u'but',
  u'not',
  u'with',
  u'those',
  u'in',
  u'the',
  u'control',
  u'group.']

tags=['O',
  'O',
  'O',
  'O',
  'I-Task',
  'I-Task',
  'I-Task',
  'I-Task',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'B-Process',
  'I-Process',
  'I-Process',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'B-Process',
  'I-Process',
  'I-Process',
  'I-Process',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'I-Process',
  'I-Process',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'B-Process',
  'I-Process',
  'I-Process',
  'O',
  'O',
  'O',
  'I-Process',
  'I-Process',
  'I-Process',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O']

# %%
words=[u'A',
  u'hydroxyl-functionalized',
  u'poly(butylene',
  u'succinate)',
  u'based',
  u'polyester',
  u'was',
  u'prepared',
  u'by',
  u'conventional',
  u'polycondensation',
  u'of',
  u'benzyl-protected',
  u'dimethyl',
  u'malonate',
  u'and',
  u'1,4-butanediol',
  u'(Scheme',
  u'2(a))',
  u'[24a].',
  u'Yao',
  u'et\xa0al.',
  u'reported',
  u'on',
  u'the',
  u'direct',
  u'polycondensation',
  u'of',
  u'l-lactic',
  u'acid',
  u'and',
  u'citric',
  u'acid',
  u'with',
  u'the',
  u'formation',
  u'of',
  u'poly[(l-lactic',
  u'acid)-co-(citric',
  u'acid)],',
  u'obtaining',
  u'a',
  u'polyester',
  u'oligomer',
  u'with',
  u'both',
  u'pendant',
  u'carboxylic',
  u'and',
  u'hydroxyl',
  u'groups',
  u'[24b].',
  u'This',
  u'PLCA',
  u'oligomer',
  u'was',
  u'reacted',
  u'with',
  u'dihydroxylated',
  u'PLLA',
  u'as',
  u'a',
  u'macromonomer,',
  u'yielding',
  u'a',
  u'PLCA\u2013PLLA',
  u'multiblock',
  u'copolymer',
  u'as',
  u'shown',
  u'in',
  u'Scheme',
  u'2(b).',
  u'While',
  u'lipases',
  u'have',
  u'been',
  u'investigated',
  u'for',
  u'the',
  u'ring-opening',
  u'polymerization',
  u'(ROP)',
  u'of',
  u'cyclic',
  u'ester',
  u'monomers',
  u'[25,26],',
  u'they',
  u'have',
  u'also',
  u'been',
  u'used',
  u'for',
  u'the',
  u'preparation',
  u'of',
  u'polyesters',
  u'by',
  u'polycondensation',
  u'reactions.',
  u'The',
  u'advantage',
  u'of',
  u'this',
  u'technique',
  u'is',
  u'that',
  u'these',
  u'enzyme-catalyzed',
  u'reactions',
  u'proceed',
  u'without',
  u'protection',
  u'of',
  u'the',
  u'pendant',
  u'functional',
  u'groups.',
  u'In',
  u'this',
  u'field,',
  u'hydroxyl-bearing',
  u'polyesters',
  u'have',
  u'been',
  u'synthesized',
  u'by',
  u'the',
  u'copolymerization',
  u'of',
  u'divinyl',
  u'adipate',
  u'with',
  u'various',
  u'triols',
  u'(e.g.',
  u'glycerol,',
  u'1,2,4-butanetriol)',
  u'as',
  u'represented',
  u'in',
  u'Scheme',
  u'2(c)',
  u'[27]',
  u'and',
  u'by',
  u'copolymerizations',
  u'of',
  u'1,8-octanediol',
  u'with',
  u'adipic',
  u'acid',
  u'and',
  u'several',
  u'alditols',
  u'[28].',
  u'Very',
  u'recently,',
  u'several',
  u'\u03b1-hydroxy',
  u'acids',
  u'derived',
  u'from',
  u'amino',
  u'acids',
  u'were',
  u'homo-',
  u'and',
  u'copolymerized',
  u'with',
  u'lactic',
  u'acid',
  u'by',
  u'polycondensation',
  u'in',
  u'bulk',
  u'without',
  u'protected',
  u'monomers',
  u'(Scheme',
  u'2(d))',
  u'[29].',
  u'Biodegradable',
  u'polyesters',
  u'with',
  u'various',
  u'pendant',
  u'groups',
  u'were',
  u'obtained,',
  u'although',
  u'the',
  u'molecular',
  u'weights',
  u'remained',
  u'low',
  u'(1000\u20133000gmol\u22121).']

tags= ['O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'B-Material',
  'I-Material',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'B-Material',
  'I-Material',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'B-Material',
  'I-Material',
  'O',
  'O',
  'O',
  'O',
  'O',
  'B-Material',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'B-Material',
  'I-Material',
  'I-Material',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'I-Material',
  'I-Material',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'I-Material',
  'O',
  'O',
  'O',
  'I-Material',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'I-Material',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'I-Material',
  'O',
  'O',
  'O',
  'B-Material',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O',
  'O']

# %%
gold_tags = [w.split(' ')[1] for w in gold]

# %%
nwords=45
sentence=' '.join(words[:nwords])
sentence
# Out:
# u'A hydroxyl-functionalized poly(butylene succinate) based polyester was prepared by conventional polycondensation of benzyl-protected dimethyl malonate and 1,4-butanediol (Scheme 2(a)) [24a]. Yao et\xa0al. reported on the direct polycondensation of l-lactic acid and citric acid with the formation of poly[(l-lactic acid)-co-(citric acid)], obtaining a polyester oligomer with'

# %%
' '.join([w + '_' +t for w,t in zip(words, gold_tags)][:nwords])
# Out:
# u'A_O hydroxyl-functionalized_O poly(butylene_O succinate)_O based_O polyester_B-Material was_O prepared_O by_O conventional_O polycondensation_B-Process of_O benzyl-protected_O dimethyl_B-Material malonate_I-Material and_O 1,4-butanediol_B-Material (Scheme_O 2(a))_O [24a]._O Yao_O et\xa0al._O reported_O on_O the_O direct_O polycondensation_O of_O l-lactic_B-Material acid_I-Material and_O citric_O acid_O with_O the_O formation_O of_O poly[(l-lactic_O acid)-co-(citric_O acid)],_O obtaining_O a_O polyester_B-Material oligomer_I-Material with_O'

# %%
' '.join([w + '_' +t for w,t in zip(words, tags)][:nwords])
# Out:
# u'A_O hydroxyl-functionalized_O poly(butylene_O succinate)_O based_O polyester_O was_O prepared_O by_O conventional_O polycondensation_O of_O benzyl-protected_B-Material dimethyl_I-Material malonate_O and_O 1,4-butanediol_O (Scheme_O 2(a))_O [24a]._O Yao_O et\xa0al._O reported_O on_O the_O direct_O polycondensation_O of_O l-lactic_B-Material acid_I-Material and_O citric_O acid_O with_O the_O formation_O of_O poly[(l-lactic_O acid)-co-(citric_O acid)],_O obtaining_O a_O polyester_O oligomer_O with_O'

# %%
print '\n'.join([w + '_' + str(t1==t2 and t1!='O')  for w,t1,t2 in zip(words, gold_tags, tags)])
# Out:
# A_False
# hydroxyl-functionalized_False
# poly(butylene_False
# succinate)_False
# based_False
# polyester_False
# was_False
# prepared_False
# by_False
# conventional_False
# polycondensation_False
# of_False
# benzyl-protected_False
# dimethyl_False
# malonate_False
# and_False
# 1,4-butanediol_False
# (Scheme_False
# 2(a))_False
# [24a]._False
# Yao_False
# et al._False
# reported_False
# on_False
# the_False
# direct_False
# polycondensation_False
# of_False
# l-lactic_True
# acid_True
# and_False
# citric_False
# acid_False
# with_False
# the_False
# formation_False
# of_False
# poly[(l-lactic_False
# acid)-co-(citric_False
# acid)],_False
# obtaining_False
# a_False
# polyester_False
# oligomer_False
# with_False
# both_False
# pendant_False
# carboxylic_False
# and_False
# hydroxyl_False
# groups_False
# [24b]._False
# This_False
# PLCA_True
# oligomer_False
# was_False
# reacted_False
# with_False
# dihydroxylated_False
# PLLA_False
# as_False
# a_False
# macromonomer,_False
# yielding_False
# a_False
# PLCA–PLLA_True
# multiblock_True
# copolymer_True
# as_False
# shown_False
# in_False
# Scheme_False
# 2(b)._False
# While_False
# lipases_False
# have_False
# been_False
# investigated_False
# for_False
# the_False
# ring-opening_False
# polymerization_False
# (ROP)_False
# of_False
# cyclic_False
# ester_False
# monomers_False
# [25,26],_False
# they_False
# have_False
# also_False
# been_False
# used_False
# for_False
# the_False
# preparation_False
# of_False
# polyesters_False
# by_False
# polycondensation_False
# reactions._False
# The_False
# advantage_False
# of_False
# this_False
# technique_False
# is_False
# that_False
# these_False
# enzyme-catalyzed_False
# reactions_False
# proceed_False
# without_False
# protection_False
# of_False
# the_False
# pendant_False
# functional_False
# groups._False
# In_False
# this_False
# field,_False
# hydroxyl-bearing_False
# polyesters_False
# have_False
# been_False
# synthesized_False
# by_False
# the_False
# copolymerization_False
# of_False
# divinyl_False
# adipate_False
# with_False
# various_False
# triols_False
# (e.g._False
# glycerol,_False
# 1,2,4-butanetriol)_False
# as_False
# represented_False
# in_False
# Scheme_False
# 2(c)_False
# [27]_False
# and_False
# by_False
# copolymerizations_False
# of_False
# 1,8-octanediol_False
# with_False
# adipic_False
# acid_False
# and_False
# several_False
# alditols_False
# [28]._False
# Very_False
# recently,_False
# several_False
# α-hydroxy_False
# acids_False
# derived_False
# from_False
# amino_False
# acids_False
# were_False
# homo-_False
# and_False
# copolymerized_False
# with_False
# lactic_False
# acid_False
# by_False
# polycondensation_False
# in_False
# bulk_False
# without_False
# protected_False
# monomers_False
# (Scheme_False
# 2(d))_False
# [29]._False
# Biodegradable_False
# polyesters_False
# with_False
# various_False
# pendant_False
# groups_False
# were_False
# obtained,_False
# although_False
# the_False
# molecular_False
# weights_False
# remained_False
# low_False
# (1000–3000gmol−1)._False

# %%
zip(words, gold_tags)
# Out:
# [(u'A', u'O'),
#  (u'hydroxyl-functionalized', u'O'),
#  (u'poly(butylene', u'O'),
#  (u'succinate)', u'O'),
#  (u'based', u'O'),
#  (u'polyester', u'B-Material'),
#  (u'was', u'O'),
#  (u'prepared', u'O'),
#  (u'by', u'O'),
#  (u'conventional', u'O'),
#  (u'polycondensation', u'B-Process'),
#  (u'of', u'O'),
#  (u'benzyl-protected', u'O'),
#  (u'dimethyl', u'B-Material'),
#  (u'malonate', u'I-Material'),
#  (u'and', u'O'),
#  (u'1,4-butanediol', u'B-Material'),
#  (u'(Scheme', u'O'),
#  (u'2(a))', u'O'),
#  (u'[24a].', u'O'),
#  (u'Yao', u'O'),
#  (u'et\xa0al.', u'O'),
#  (u'reported', u'O'),
#  (u'on', u'O'),
#  (u'the', u'O'),
#  (u'direct', u'O'),
#  (u'polycondensation', u'O'),
#  (u'of', u'O'),
#  (u'l-lactic', u'B-Material'),
#  (u'acid', u'I-Material'),
#  (u'and', u'O'),
#  (u'citric', u'O'),
#  (u'acid', u'O'),
#  (u'with', u'O'),
#  (u'the', u'O'),
#  (u'formation', u'O'),
#  (u'of', u'O'),
#  (u'poly[(l-lactic', u'O'),
#  (u'acid)-co-(citric', u'O'),
#  (u'acid)],', u'O'),
#  (u'obtaining', u'O'),
#  (u'a', u'O'),
#  (u'polyester', u'B-Material'),
#  (u'oligomer', u'I-Material'),
#  (u'with', u'O'),
#  (u'both', u'O'),
#  (u'pendant', u'O'),
#  (u'carboxylic', u'O'),
#  (u'and', u'O'),
#  (u'hydroxyl', u'O'),
#  (u'groups', u'O'),
#  (u'[24b].', u'O'),
#  (u'This', u'O'),
#  (u'PLCA', u'B-Material'),
#  (u'oligomer', u'I-Material'),
#  (u'was', u'O'),
#  (u'reacted', u'O'),
#  (u'with', u'O'),
#  (u'dihydroxylated', u'B-Material'),
#  (u'PLLA', u'I-Material'),
#  (u'as', u'O'),
#  (u'a', u'O'),
#  (u'macromonomer,', u'O'),
#  (u'yielding', u'O'),
#  (u'a', u'O'),
#  (u'PLCA\u2013PLLA', u'B-Material'),
#  (u'multiblock', u'I-Material'),
#  (u'copolymer', u'I-Material'),
#  (u'as', u'I-Material'),
#  (u'shown', u'I-Material'),
#  (u'in', u'I-Material'),
#  (u'Scheme', u'O'),
#  (u'2(b).', u'O'),
#  (u'While', u'O'),
#  (u'lipases', u'O'),
#  (u'have', u'O'),
#  (u'been', u'O'),
#  (u'investigated', u'O'),
#  (u'for', u'O'),
#  (u'the', u'O'),
#  (u'ring-opening', u'O'),
#  (u'polymerization', u'O'),
#  (u'(ROP)', u'O'),
#  (u'of', u'O'),
#  (u'cyclic', u'B-Material'),
#  (u'ester', u'B-Process'),
#  (u'monomers', u'I-Process'),
#  (u'[25,26],', u'O'),
#  (u'they', u'B-Process'),
#  (u'have', u'O'),
#  (u'also', u'O'),
#  (u'been', u'B-Material'),
#  (u'used', u'I-Material'),
#  (u'for', u'I-Material'),
#  (u'the', u'O'),
#  (u'preparation', u'O'),
#  (u'of', u'O'),
#  (u'polyesters', u'O'),
#  (u'by', u'O'),
#  (u'polycondensation', u'O'),
#  (u'reactions.', u'O'),
#  (u'The', u'O'),
#  (u'advantage', u'O'),
#  (u'of', u'O'),
#  (u'this', u'O'),
#  (u'technique', u'O'),
#  (u'is', u'B-Process'),
#  (u'that', u'O'),
#  (u'these', u'O'),
#  (u'enzyme-catalyzed', u'O'),
#  (u'reactions', u'O'),
#  (u'proceed', u'O'),
#  (u'without', u'O'),
#  (u'protection', u'O'),
#  (u'of', u'O'),
#  (u'the', u'O'),
#  (u'pendant', u'B-Process'),
#  (u'functional', u'O'),
#  (u'groups.', u'O'),
#  (u'In', u'O'),
#  (u'this', u'O'),
#  (u'field,', u'O'),
#  (u'hydroxyl-bearing', u'O'),
#  (u'polyesters', u'O'),
#  (u'have', u'O'),
#  (u'been', u'O'),
#  (u'synthesized', u'O'),
#  (u'by', u'O'),
#  (u'the', u'O'),
#  (u'copolymerization', u'B-Material'),
#  (u'of', u'I-Material'),
#  (u'divinyl', u'O'),
#  (u'adipate', u'O'),
#  (u'with', u'O'),
#  (u'various', u'O'),
#  (u'triols', u'O'),
#  (u'(e.g.', u'B-Process'),
#  (u'glycerol,', u'O'),
#  (u'1,2,4-butanetriol)', u'B-Material'),
#  (u'as', u'I-Material'),
#  (u'represented', u'O'),
#  (u'in', u'O'),
#  (u'Scheme', u'O'),
#  (u'2(c)', u'O'),
#  (u'[27]', u'O'),
#  (u'and', u'O'),
#  (u'by', u'O'),
#  (u'copolymerizations', u'O'),
#  (u'of', u'O'),
#  (u'1,8-octanediol', u'O'),
#  (u'with', u'O'),
#  (u'adipic', u'O'),
#  (u'acid', u'O'),
#  (u'and', u'O'),
#  (u'several', u'B-Process'),
#  (u'alditols', u'O'),
#  (u'[28].', u'B-Material'),
#  (u'Very', u'O'),
#  (u'recently,', u'O'),
#  (u'several', u'O'),
#  (u'\u03b1-hydroxy', u'O'),
#  (u'acids', u'O'),
#  (u'derived', u'O'),
#  (u'from', u'O'),
#  (u'amino', u'O'),
#  (u'acids', u'O'),
#  (u'were', u'O'),
#  (u'homo-', u'I-Material'),
#  (u'and', u'I-Material'),
#  (u'copolymerized', u'O'),
#  (u'with', u'O'),
#  (u'lactic', u'O'),
#  (u'acid', u'O'),
#  (u'by', u'O'),
#  (u'polycondensation', u'O'),
#  (u'in', u'O'),
#  (u'bulk', u'O'),
#  (u'without', u'O'),
#  (u'protected', u'O'),
#  (u'monomers', u'O'),
#  (u'(Scheme', u'O'),
#  (u'2(d))', u'O'),
#  (u'[29].', u'O'),
#  (u'Biodegradable', u'O'),
#  (u'polyesters', u'O'),
#  (u'with', u'O'),
#  (u'various', u'O'),
#  (u'pendant', u'B-Process'),
#  (u'groups', u'O'),
#  (u'were', u'B-Material'),
#  (u'obtained,', u'I-Material'),
#  (u'although', u'B-Material'),
#  (u'the', u'I-Material'),
#  (u'molecular', u'I-Material'),
#  (u'weights', u'O'),
#  (u'remained', u'O'),
#  (u'low', u'O'),
#  (u'(1000\u20133000gmol\u22121).', u'O')]
